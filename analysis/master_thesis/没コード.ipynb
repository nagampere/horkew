# %%
# 2020年対象の事業所数/住宅数比率の算出
URL = 'http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData'
p = {'appId':'6f812f8eb28dc679954f0eef1472fca422edc08d',
     'lang':'J',
     'statsDataId':'0004005640',
     # 'metaGetFlg':'N',
     'explanationGetFlg':'N',
     'annotationGetFlg':'N',
     'cdTab':'102-2021',
     'cdCat01':'0',
     # 'cdArea':','.join(jcode),
     # # 'cdCat02':','.join(jcode)
     # 'lvArea':'5-',
     'cdAreaFrom': From,
     'cdAreaTo': To
     }
res = requests.get(URL,p)
text = res.json()
print('項目名：',text['GET_STATS_DATA']['STATISTICAL_DATA']['TABLE_INF']['TITLE']['$'])
print('ヒット件数：',text['GET_STATS_DATA']['STATISTICAL_DATA']['RESULT_INF']['TOTAL_NUMBER'])
text['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
df = pd.DataFrame(text['GET_STATS_DATA']['STATISTICAL_DATA']['DATA_INF']['VALUE'])

df_theta_i = pd.DataFrame(0,index=jcode,columns=['office','house'])
for i in df.itertuples():
    try: 
        if i[6] == '-': pass
        else: df_theta_i.at[i[3],'office'] += int(i[6])
    except: pass

URL = 'http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData'
p = {'appId':'6f812f8eb28dc679954f0eef1472fca422edc08d',
     'lang':'J',
     'statsDataId':'0003355290',
     # 'metaGetFlg':'N',
     'explanationGetFlg':'N',
     'annotationGetFlg':'N',
     'cdCat01':'0',
     # 'cdArea':','.join(jcode),
     # # 'cdCat02':','.join(jcode)
     # 'lvArea':'5-',
     'cdAreaFrom': From,
     'cdAreaTo': To
     }

res = requests.get(URL,p)
text = res.json()
print('項目名：',text['GET_STATS_DATA']['STATISTICAL_DATA']['TABLE_INF']['TITLE']['$'])
print('ヒット件数：',text['GET_STATS_DATA']['STATISTICAL_DATA']['RESULT_INF']['TOTAL_NUMBER'])
text['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']

df = pd.DataFrame(text['GET_STATS_DATA']['STATISTICAL_DATA']['DATA_INF']['VALUE'])
for i in df.itertuples():
    try: 
        if i[6] == '-': pass
        else: df_theta_i.at[i[3],'house'] += int(i[6])
    except: pass

df_theta_i['theta_i'] = df_theta_i['office']/df_theta_i['house']
df_theta_i = df_theta_i.round(6).drop(columns=['office','house']).reset_index(names='jcode')
df_theta_i

# %%
# 2020年対象の事業所数/住宅数比率の算出
URL = 'http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData'
p = {'appId':'6f812f8eb28dc679954f0eef1472fca422edc08d',
     'lang':'J',
     'statsDataId':'0003085552',
     # 'metaGetFlg':'N',
     'explanationGetFlg':'N',
     'annotationGetFlg':'N',
     'cdTab':'832',
     # 'cdArea':','.join(jcode),
     # # 'cdCat02':','.join(jcode)
     # 'lvArea':'5-',
     'cdCat01From': From,
     'cdCat01To': To
     }

res = requests.get(URL,p)
text = res.json()
print('項目名：',text['GET_STATS_DATA']['STATISTICAL_DATA']['TABLE_INF']['TITLE']['$'])
print('ヒット件数：',text['GET_STATS_DATA']['STATISTICAL_DATA']['RESULT_INF']['TOTAL_NUMBER'])
text['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
df = pd.DataFrame(text['GET_STATS_DATA']['STATISTICAL_DATA']['DATA_INF']['VALUE'])
df_theta_i = pd.DataFrame(0,index=jcode,columns=['office','house'])
for i in df.itertuples():
    try: 
        if i[4] == '-': pass
        else: df_theta_i.at[i[2],'office'] += int(i[4])
    except: pass

URL = 'http://api.e-stat.go.jp/rest/3.0/app/json/getStatsData'
p = {'appId':'6f812f8eb28dc679954f0eef1472fca422edc08d',
     'lang':'J',
     'statsDataId':'0003009773',
     # 'metaGetFlg':'N',
     'explanationGetFlg':'N',
     'annotationGetFlg':'N',
     'cdCat01':'00',
     # 'cdArea':','.join(jcode),
     # # 'cdCat02':','.join(jcode)
     # 'lvArea':'5-',
     'cdAreaFrom': From,
     'cdAreaTo': To
     }
res = requests.get(URL,p)
text = res.json()
print('項目名：',text['GET_STATS_DATA']['STATISTICAL_DATA']['TABLE_INF']['TITLE']['$'])
print('ヒット件数：',text['GET_STATS_DATA']['STATISTICAL_DATA']['RESULT_INF']['TOTAL_NUMBER'])
text['GET_STATS_DATA']['STATISTICAL_DATA']['CLASS_INF']['CLASS_OBJ']
df = pd.DataFrame(text['GET_STATS_DATA']['STATISTICAL_DATA']['DATA_INF']['VALUE'])
for i in df.itertuples():
    try: 
        if i[5] == '-': pass
        else: df_theta_i.at[i[3],'house'] += int(i[5])
    except: pass
df_theta_i['theta_i'] = df_theta_i['office']/df_theta_i['house']
df_theta_i = df_theta_i.round(6).drop(columns=['office','house']).reset_index(names='jcode')
df_theta_i

# %%
jcode,
11102,1.19516007
11103,1.14974796
11104,0.77366178
11105,1.14098297
11106,0.57909915
11107,0.95397505
11108,1.59796941
11109,1.58337068
11203,0.78757993
11208,1.26109434
11219,1.06306506
11221,0.76291278
11222,1.2880026
11223,1.05263727
11224,1.21215209
11227,0.65559112
11228,1.20016027
11229,0.50000021
11230,0.83827028
11234,0.81893593
11235,1.13021927
11237,1.23942572
11245,0.55557639
12101,0.97550844
12102,1.40719142
12103,1.04149109
12106,0.87939659
12203,0.86989309
12204,1.63123205
12207,2.06586652
12216,0.60610325
12220,1.36514696
12224,1.25260032
12227,1.13649481
13101,0.55647028
13102,0.5362798
13103,0.53167793
13104,0.62780807
13105,0.83427577
13106,0.68525221
13107,0.79326757
13108,0.78233869
13109,0.54736818
13110,1.12323067
13111,1.84695053
13112,1.87202513
13113,0.58762191
13114,2.15003802
13115,1.15735236
13116,0.76343319
13117,1.1443385
13118,0.8360755
13119,0.85840236
13120,1.98003206
13121,1.02260067
13122,1.05177276
13123,1.35084762
13202,0.71285619
13203,0.92356902
13204,1.24322087
13206,1.33595754
13207,1.6485014
13208,1.06331607
13209,0.67308502
13210,1.29540315
13211,1.35562261
13212,1.03499387
13213,0.53125495
13214,1.13486648
13215,0.6141012
13218,1.62460027
13219,0.6574809
13220,1.0472257
13221,1.29887458
13222,1.15897265
13223,1.07409059
13224,0.6134923
13225,1.37625266
13227,0.79922085
13229,0.84648644
14101,1.2569205
14102,0.90624586
14103,0.68448924
14104,1.03642987
14105,1.27956271
14106,1.33161938
14107,1.30552797
14108,1.17386016
14109,0.96704172
14110,1.33053348
14111,1.35966092
14112,0.93615434
14113,1.19142186
14114,1.47955736
14115,0.69255235
14116,1.03763574
14117,1.10602511
14118,1.0647967
14131,1.0670226
14132,1.24304134
14133,0.89754775
14134,0.88367006
14135,1.25658295
14136,1.05476143
14137,1.32461945
14204,1.26445557
14205,1.36804033
14207,2.18865139
14213,1.22408699
14215,2.28277667
14216,1.202512
